# %% [markdown]
# <a href="https://colab.research.google.com/github/tmdvltuf123/homework/blob/main/week09_%EC%9D%B8%EA%B8%B0%EA%B0%95%EC%A2%8C%EC%9D%98%EB%B9%88%EB%8F%84%EC%88%98%EA%B7%B8%EB%9E%98%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
course = {'TOEIC':0, 'TOEFL':0, 'TOEIC SPEAKING':0, 'OPIC':0, 'IELTS':0}

print('수강하고 싶은 강좌를 입력하세요.')
print('복수 개의 강좌를 입력하려면 콤마로 구분하세요.')

while True :
  s = input('TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: ')
  if s =='종료' :
    break
  for a in s.split(',') :
    if a in course :
      course[a] += 1
    else :
      print(f'{a}는 등록되지 않은 강좌입니다.')

for key, value in course.items() :
  print(key, value)
# Out:
# 수강하고 싶은 강좌를 입력하세요.
# 복수 개의 강좌를 입력하려면 콤마로 구분하세요.
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: TOEIC
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: TOEIC,TOEFL
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: OPIC
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: IELTS
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: 종료
# TOEIC 2
# TOEFL 1
# TOEIC SPEAKING 0
# OPIC 1
# IELTS 1

# %%
import matplotlib.pyplot as plt

course = {'TOEIC':0, 'TOEFL':0, 'TOEIC SPEAKING':0, 'OPIC':0, 'IELTS':0}

print('수강하고 싶은 강좌를 입력하세요.')
print('복수 개의 강좌를 입력하려면 콤마로 구분하세요.')

while True :
  s = input('TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: ')
  if s =='종료' :
    break
  for a in s.split(',') :
    if a in course :
      course[a] += 1
    else :
      print(f'{a}는 등록되지 않은 강좌입니다.')

plt.figure(figsize=(5.5,3))
plt.bar(course.keys(), course.values(), color='g', width=0.6)
plt.title('preferred english course')
plt.xlabel('english course')
plt.ylabel('frequency')
plt.show()
# Out:
# 수강하고 싶은 강좌를 입력하세요.
# 복수 개의 강좌를 입력하려면 콤마로 구분하세요.
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: TOEIC
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: TOEFL
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: TOEIC,OPIC
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: OPIC,IELTS
# TOEIC, TOEFL, TOEIC SPEAKING, OPIC, IELTS, 종료: 종료
